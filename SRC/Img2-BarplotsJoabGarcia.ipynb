# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('weatherAUS.csv')
df_states=pd.read_csv('aus_cities.csv', index_col=0)
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
df = pd.DataFrame(df, columns = ['Date', 'Location', 'Rainfall', 'MaxTemp'])
syd_rain = df.loc[df['Location'] == 'Sydney']
syd_rain
# Out:
#              Date Location  Rainfall  MaxTemp
# 30176  2008-02-01   Sydney      15.6     22.4
# 30177  2008-02-02   Sydney       6.0     25.6
# 30178  2008-02-03   Sydney       6.6     24.5
# 30179  2008-02-04   Sydney      18.8     22.8
# 30180  2008-02-05   Sydney      77.4     25.7
# ...           ...      ...       ...      ...
# 33515  2017-06-21   Sydney       0.0     19.6
# 33516  2017-06-22   Sydney       0.0     19.2
# 33517  2017-06-23   Sydney       0.0     17.7
# 33518  2017-06-24   Sydney       0.0     19.3
# 33519  2017-06-25   Sydney       0.0     19.3
#
# [3344 rows x 4 columns]

# %%
df = pd.DataFrame(df, columns = ['Date', 'Location', 'Rainfall', 'MaxTemp'])
ade_rain = df.loc[df['Location'] == 'Adelaide']
ade_rain
# Out:
#              Date  Location  Rainfall  MaxTemp
# 96320  2008-07-01  Adelaide       5.0     15.7
# 96321  2008-07-02  Adelaide       0.8     15.8
# 96322  2008-07-03  Adelaide       0.0     15.1
# 96323  2008-07-04  Adelaide       0.0     15.9
# 96324  2008-07-05  Adelaide       0.0     15.4
# ...           ...       ...       ...      ...
# 99508  2017-06-21  Adelaide       0.0     19.2
# 99509  2017-06-22  Adelaide       0.0     19.5
# 99510  2017-06-23  Adelaide       0.0     18.5
# 99511  2017-06-24  Adelaide       0.0     17.3
# 99512  2017-06-25  Adelaide       0.0      NaN
#
# [3193 rows x 4 columns]

# %%
df = pd.DataFrame(df, columns = ['Date', 'Location', 'Rainfall', 'MaxTemp'])
mel_rain = df.loc[df['Location'] == 'Melbourne']
mel_rain
# Out:
#              Date   Location  Rainfall  MaxTemp
# 67200  2008-07-01  Melbourne       2.0     15.4
# 67201  2008-07-02  Melbourne       0.6     14.5
# 67202  2008-07-03  Melbourne       1.4     14.1
# 67203  2008-07-04  Melbourne       0.6     14.5
# 67204  2008-07-05  Melbourne       0.0     15.5
# ...           ...        ...       ...      ...
# 70388  2017-06-21  Melbourne       0.6     13.5
# 70389  2017-06-22  Melbourne       0.2     14.1
# 70390  2017-06-23  Melbourne       0.0     14.9
# 70391  2017-06-24  Melbourne       1.4     12.3
# 70392  2017-06-25  Melbourne       0.0     14.3
#
# [3193 rows x 4 columns]

# %%
df = pd.DataFrame(df, columns = ['Date', 'Location', 'Rainfall', 'MaxTemp'])
bris_rain = df.loc[df['Location'] == 'Brisbane']
bris_rain
# Out:
#              Date  Location  Rainfall  MaxTemp
# 84007  2008-07-01  Brisbane       0.0     25.2
# 84008  2008-07-02  Brisbane       0.0     22.9
# 84009  2008-07-03  Brisbane       0.0     22.4
# 84010  2008-07-04  Brisbane       0.8     20.0
# 84011  2008-07-05  Brisbane       0.0     16.7
# ...           ...       ...       ...      ...
# 87195  2017-06-21  Brisbane       0.0     23.4
# 87196  2017-06-22  Brisbane       0.0     22.7
# 87197  2017-06-23  Brisbane       0.0     23.7
# 87198  2017-06-24  Brisbane       0.0     24.5
# 87199  2017-06-25  Brisbane       0.0     24.2
#
# [3193 rows x 4 columns]

# %%
syd_rain.dropna()
plt.bar(syd_rain.Rainfall/5, syd_rain.MaxTemp/2)
plt.xlabel('Rainfall' + " (in cm)")
plt.ylabel('Max Temp' + " (in Celsius)")
plt.suptitle('Sydney Rainfall & Max Temp')
plt.show()

# %%
ade_rain.dropna()
plt.bar(ade_rain.Rainfall/5, ade_rain.MaxTemp/2)
plt.xlabel('Rainfall' + " (in cm)")
plt.ylabel('Max Temp' + " (in Celsius)")
plt.suptitle('Adelaide Rainfall & Max Temp')
plt.show()

# %%
mel_rain.dropna()
plt.bar(mel_rain.Rainfall/5, mel_rain.MaxTemp/2)
plt.xlabel('Rainfall' + " (in cm)")
plt.ylabel('Max Temp' + " (in Celsius)")
plt.suptitle('Melbourne Rainfall & Max Temp')
plt.show()

# %%
plt.bar(bris_rain.Rainfall/5, bris_rain.MaxTemp/2)
plt.xlabel('Rainfall' + " (in cm)")
plt.ylabel('Max Temp' + " (in Celsius)")
plt.suptitle('Brisbane Rainfall & Max Temp')
plt.show()
